# %%
import theano

import cPickle as pkl
import numpy as np

from collections import OrderedDict, defaultdict
from scipy.linalg import norm

import tools
import datasource
from utils import *
from utils import load_params, init_tparams
from model import init_params, build_sentence_encoder, build_image_encoder, build_errors
from datasets import load_dataset
import matplotlib.pyplot as plt

from numpy import linalg as LA
import numpy as np
# %matplotlib inline

# %%
print 'Loading dataset'
model = tools.load_model('snapshots/sentence-image-finetuned-t100-lmdb1-topic-insert_0.2_order_1')
model_options = model['options']
model_options['cnn'] = 'finetuned_t100_10crop_lmdb1'
dataset = load_dataset(model_options['data'], cnn=model_options['cnn'], load_train=True)
dev = dataset['dev']    #val set
dev = datasource.Datasource(dev, worddict=model['worddict'])
dev_caps, dev_ims, dev_cap_tps, dev_im_tps = dev.all()


topic_vectors = tools.encode_topics(model, np.eye(100,dtype='float32'))
img_vectors = tools.encode_images(model, dev_ims)
sentence_vectors = tools.encode_sentences(model, dev_caps)
# Out:
# Loading dataset
# snapshots/sentence-image-finetuned-t100-lmdb1-topic-insert_0.2_order_1
# Loading model
# Loading model parameters...
# Compiling sentence encoder...
# /home/wujian/anaconda2/lib/python2.7/site-packages/theano/scan_module/scan.py:1017: Warning: In the strict mode, all neccessary shared variables must be passed as a part of non_sequences
#   'must be passed as a part of non_sequences', Warning)
# Compiling image encoder...
# Compiling topic encoder...
# Compiling error computation...
# Packing up...

# %%
img_tmp = np.load('../neuraltalk2/tmp.npy')
print(img_tmp.shape)
print(tools.encode_images(model, img_tmp))
np.save('../neuraltalk2/tmp2.npy', tools.encode_images(model, img_tmp))
# Out:
# (1, 4096)
# [[ 0.          0.          0.01061621 ...,  0.          0.00424775  0.        ]]

# %%
for indx in range(50) :
    print(np.argsort(0 - dev_cap_tps[indx])[0:5])
    print(np.argsort(0 - dev_im_tps[indx/5])[0:5])
    print((topic_vectors[dev_cap_tps[indx].argmax()] - sentence_vectors[indx]).sum())
    print((img_vectors[indx/5] - sentence_vectors[indx]).sum())
    if indx % 5 == 4 :
        print('----------------------')
# Out:
# [30 34 61 38 60]
# [33 85 18 26 46]
# -2.90387
# -1.27186
# [30 61 85 33 46]
# [33 85 18 26 46]
# -2.78147
# -1.14947
# [33 30 38 61  0]
# [33 85 18 26 46]
# -3.89875
# -1.21878
# [33 30 38  0 71]
# [33 85 18 26 46]
# -3.59763
# -0.917656
# [30 38 61 47  0]
# [33 85 18 26 46]
# -2.76258
# -1.13058
# ----------------------
# [20 97 83 25 40]
# [20 81 89  7 97]
# -1.44345
# -1.2438
# [20 81  0 71 70]
# [20 81 89  7 97]
# -0.596642
# -0.396993
# [20 69 16 81  0]
# [20 81 89  7 97]
# -1.07258
# -0.87293
# [81 20 97  7 91]
# [20 81 89  7 97]
# -0.722857
# -2.00228
# [20 81 39 53 29]
# [20 81 89  7 97]
# -0.890716
# -0.691068
# ----------------------
# [87 60 61 79 17]
# [18 13 61 60 12]
# 1.64385
# 0.311578
# [60 61 13  5 48]
# [18 13 61 60 12]
# -0.124525
# -0.766373
# [60 13 61 38 29]
# [18 13 61 60 12]
# 1.62455
# 0.982702
# [60 13 61 44 51]
# [18 13 61 60 12]
# 0.670321
# 0.0284732
# [60 13 61 98 18]
# [18 13 61 60 12]
# 0.983164
# 0.341316
# ----------------------
# [ 7 48  2  0 72]
# ...

# %%
np.save('../neuraltalk2/model/topic_tmp.npy', topic_vectors[0])

# %%
plt.hist(topic_vectors.flatten(), 100, normed=True, histtype='bar')
plt.title("value distribute")
plt.xlabel("Value")
plt.ylabel("Frequency")


plt.hist(sentence_vectors.flatten(), 100, normed=1, histtype='bar')
plt.title("value distribute")
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.hist(img_vectors.flatten(), 100, normed=1, histtype='bar')
plt.title("value distribute")
plt.xlabel("Value")
plt.ylabel("Frequency")

# %% [raw]
# symmetric
# Mean metrics:
# Text to image: 36.3, 73.3, 85.8, 2.0, 9.0
# Image to text: 45.4, 77.7, 88.7, 2.0, 5.8
#
# original
# Mean metrics:
# Text to image: 38.1, 73.7, 86.0, 2.0, 7.7
# Image to text: 46.3, 79.3, 89.2, 2.0, 5.7
#
#
#
# etc1    #??? sentense embedding no abs, img relu
# Mean metrics:
# Text to image: 39.2, 74.8, 86.5, 2.0, 7.3
# Image to text: 46.8, 80.6, 89.4, 2.0, 5.3
#
# Mean metrics:
# Text to image: 39.3, 75.1, 86.9, 2.0, 7.1
# Image to text: 47.4, 80.5, 89.8, 1.8, 5.3
#
# etc2   #all relu
# Mean metrics:
# Text to image: 38.8, 74.6, 86.4, 2.0, 7.5
# Image to text: 46.5, 79.6, 89.5, 2.0, 5.4
# Mean metrics:
# Text to image: 38.8, 74.3, 86.6, 2.0, 7.5
# Image to text: 47.0, 79.9, 89.4, 2.0, 5.5
# Mean metrics:
# Text to image: 39.1, 74.9, 86.4, 2.0, 7.6
# Image to text: 47.7, 79.5, 89.8, 2.0, 5.1
# Mean metrics:
# Text to image: 38.3, 74.7, 86.7, 2.0, 7.4
# Image to text: 46.4, 79.0, 89.4, 2.0, 5.6
# Mean metrics:
# Text to image: 39.0, 74.7, 86.5, 2.0, 7.6
# Image to text: 47.4, 79.8, 89.3, 2.0, 5.3
# mean::::::
# Text to image: 38.8 ,  74.64,  86.52,   2.  ,   7.52
# Image to text:  47.  ,  79.56,  89.48,   2.  ,   5.38
#
#
#
# etc2_hyper_m0p1_1
# Mean metrics:
# Text to image: 38.7, 74.6, 86.3, 2.0, 7.5
# Image to text: 47.5, 79.3, 89.1, 2.0, 5.3
#
#
# etc3   #al no abs
# Mean metrics:
# Text to image: 37.3, 72.7, 84.9, 2.0, 8.2
# Image to text: 45.6, 79.2, 89.4, 2.0, 5.3
#
# etc4   # img embedding no abs, sentense relu
# Mean metrics:
# Text to image: 37.3, 73.2, 85.2, 2.0, 8.1
# Image to text: 46.6, 79.7, 89.7, 1.8, 5.4
#
# sentence-image-finetuned-t100_order_1:
# Mean metrics:
# Text to image: 41.5, 77.1, 88.2, 2.0, 6.5
# Image to text: 50.4, 82.0, 90.4, 1.4, 4.8
#
# sentence-image-finetuned-t100-lmdb1-topic-insert_0.2_1paironly_order_1:
# Mean metrics:
# Text to image: 41.8, 77.4, 88.2, 2.0, 6.6
# Image to text: 49.6, 82.2, 91.1, 1.8, 4.9
#
# sentence-image-finetuned-t100-lmdb1-topic-insert_0.2_order_1:
# Mean metrics:
# Text to image: 40.4, 76.6, 87.8, 2.0, 6.5
# Image to text: 48.5, 80.6, 89.6, 1.6, 4.8
#
# sentence-image-finetuned-t100-lmdb1-topic-insert_0.1_order_1:
# Mean metrics:
# Text to image: 40.9, 76.7, 88.2, 2.0, 6.3
# Image to text: 48.3, 80.6, 90.3, 2.0, 4.9
#
# sentence-image-finetuned-t200-lmdb1_order_1:
# Mean metrics:
# Text to image: 42.5, 77.9, 88.6, 2.0, 6.6
# Image to text: 52.0, 83.2, 91.7, 1.0, 4.6
#
# sentence-image-finetuned-t100-lmdb2_order_1:
# Mean metrics:
# Text to image: 42.0, 77.6, 88.6, 2.0, 6.6
# Image to text: 50.0, 81.7, 91.1, 1.2, 4.5
#
# sentence-image-finetuned-t200-lmdb2_order_1:
# Mean metrics:
# Text to image: 41.5, 76.9, 88.0, 2.0, 7.0
# Image to text: 49.0, 82.0, 90.9, 1.8, 4.7

# %%
import tools, evaluation
model = tools.load_model('snapshots/sentence-image-finetuned-t200-lmdb2_order_1')
evaluation.ranking_eval_5fold(model, split='test')
# Out:
# snapshots/sentence-image-finetuned-t200-lmdb2_order_1
# Loading model
# Loading model parameters...
# Compiling sentence encoder...
# Compiling image encoder...
# Compiling error computation...
# Packing up...
# Loading fold 0
# Computing results...
# Text to image: 42.5, 78.0, 89.0, 2.0, 6.6
# Image to text: 51.6, 83.2, 90.9, 1.0, 4.2
# Loading fold 1
# Computing results...
# Text to image: 42.8, 76.5, 87.1, 2.0, 7.6
# Image to text: 49.1, 81.7, 90.8, 2.0, 5.1
# Loading fold 2
# Computing results...
# Text to image: 41.3, 76.8, 88.3, 2.0, 7.3
# Image to text: 49.7, 83.5, 91.6, 2.0, 5.0
# Loading fold 3
# Computing results...
# Text to image: 39.3, 75.0, 86.9, 2.0, 6.7
# Image to text: 47.1, 79.0, 89.4, 2.0, 5.2
# Loading fold 4
# Computing results...
# Text to image: 41.7, 78.2, 88.7, 2.0, 6.5
# Image to text: 47.6, 82.8, 91.6, 2.0, 4.0
# -----------------------------------
# Mean metrics:
# Text to image: 41.5, 76.9, 88.0, 2.0, 7.0
# Image to text: 49.0, 82.0, 90.9, 1.8, 4.7
